# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data',header=None, na_values=['NA'])

# %%
df.columns=['ID', 'Clump_Thickness', 'U_Cell_Size', 'U_Cell_Shape','Marg_Adhes', 'Epi_Cell_Size', 'Bare_Nuc', 'Chromatin', 'Nucleoli','Mitoses', 'Class']

# %%
cols = ['Clump_Thickness', 'U_Cell_Size', 'U_Cell_Shape','Marg_Adhes', 'Epi_Cell_Size', 'Chromatin', 'Nucleoli','Mitoses']

# %%
df.head()
# Out:
#         ID  Clump_Thickness  U_Cell_Size  U_Cell_Shape  Marg_Adhes  \
# 0  1000025                5            1             1           1
# 1  1002945                5            4             4           5
# 2  1015425                3            1             1           1
# 3  1016277                6            8             8           1
# 4  1017023                4            1             1           3
#
#    Epi_Cell_Size Bare_Nuc  Chromatin  Nucleoli  Mitoses  Class
# 0              2        1          3         1        1      2
# 1              7       10          3         2        1      2
# 2              2        2          3         1        1      2
# 3              3        4          3         7        1      2
# 4              2        1          3         1        1      2

# %%
df.head(150)
# Out:
#           ID  Clump_Thickness  U_Cell_Size  U_Cell_Shape  Marg_Adhes  \
# 0    1000025                5            1             1           1
# 1    1002945                5            4             4           5
# 2    1015425                3            1             1           1
# 3    1016277                6            8             8           1
# 4    1017023                4            1             1           3
# 5    1017122                8           10            10           8
# 6    1018099                1            1             1           1
# 7    1018561                2            1             2           1
# 8    1033078                2            1             1           1
# 9    1033078                4            2             1           1
# 10   1035283                1            1             1           1
# 11   1036172                2            1             1           1
# 12   1041801                5            3             3           3
# ...

# %%
df[cols].describe()
# Out:
#        Clump_Thickness  U_Cell_Size  U_Cell_Shape  Marg_Adhes  Epi_Cell_Size  \
# count       699.000000   699.000000    699.000000  699.000000     699.000000
# mean          4.417740     3.134478      3.207439    2.806867       3.216023
# std           2.815741     3.051459      2.971913    2.855379       2.214300
# min           1.000000     1.000000      1.000000    1.000000       1.000000
# 25%           2.000000     1.000000      1.000000    1.000000       2.000000
# 50%           4.000000     1.000000      1.000000    1.000000       2.000000
# 75%           6.000000     5.000000      5.000000    4.000000       4.000000
# max          10.000000    10.000000     10.000000   10.000000      10.000000
#
#         Chromatin    Nucleoli     Mitoses
# count  699.000000  699.000000  699.000000
# mean     3.437768    2.866953    1.589413
# std      2.438364    3.053634    1.715078
# min      1.000000    1.000000    1.000000
# 25%      2.000000    1.000000    1.000000
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
sb.pairplot(df.dropna(),vars=cols,hue = 'Class')

# %%
df.loc[df['Class']==2,'Class'] ='Benign'
df.loc[df['Class']==4,'Class'] ='Malignant'

# %%
df['Class'].unique()
# Out:
# array(['Benign', 'Malignant'], dtype=object)

# %%
df.loc[df['Class'] == 'Malignant', 'Clump_Thickness'].hist()

# %%
df.loc[(df['Class']=='Malignant') & (df['Clump_Thickness'] <5) ]
# Out:
#           ID  Clump_Thickness  U_Cell_Size  U_Cell_Shape  Marg_Adhes  \
# 39   1091262                2            5             3           3
# 46   1105257                3            7             7           4
# 84   1147699                3            5             7           8
# 86   1148278                3            3             6           4
# 87   1148873                3            6             6           6
# 101  1167439                2            3             4           4
# 107  1170420                1            6             8          10
# 117  1173509                4            5             5          10
# 146  1185609                3            4             5           2
# 186  1206695                1            5             8           6
# 222  1226012                4            1             1           3
# 267   320675                3            3             5           2
# 272   320675                3            3             5           2
# ...

# %%
df.loc[df['Class']=='Benign', 'Epi_Cell_Size'].hist()

# %%
df.loc[(df['Epi_Cell_Size'].isnull())|
             (df['Clump_Thickness'].isnull()) |
            (df['U_Cell_Size'].isnull()) |
            (df['U_Cell_Shape'].isnull())|
            (df['Marg_Adhes'].isnull())|
            (df['Bare_Nuc'].isnull())|
            (df['Chromatin'].isnull())|
            (df['Nucleoli'].isnull())|
            (df['Mitoses'].isnull())]
# Out:
# Empty DataFrame
# Columns: [ID, Clump_Thickness, U_Cell_Size, U_Cell_Shape, Marg_Adhes, Epi_Cell_Size, Bare_Nuc, Chromatin, Nucleoli, Mitoses, Class]
# Index: []

# %%
df.loc[(df['Class']=='Benign','U_Cell_Size')]
# Out:
# 0      1
# 1      4
# 2      1
# 3      8
# 4      1
# 6      1
# 7      1
# 8      1
# 9      2
# 10     1
# 11     1
# 13     1
# 16     1
# 17     1
# 19     1
# 22     1
# 24     1
# 26     2
# 27     1
# 28     1
# 29     1
# 30     1
# 31     1
# 33     1
# 34     1
# 35     1
# 37     2
# 40     6
# 45     1
# 47     1
#       ..
# 660    1
# 661    1
# 662    1
# 663    1
# 664    1
# 665    1
# 666    2
# 667    1
# 671    2
# 672    1
# 673    3
# 674    1
# 675    1
# 676    1
# 677    1
# 678    1
# 679    1
# 682    1
# 683    1
# 684    1
# 685    1
# 686    1
# 687    1
# 688    1
# 689    1
# 690    1
# 692    1
# 693    1
# 694    1
# 695    1
# Name: U_Cell_Size, Length: 458, dtype: int64

# %%
average_Clump_Thickness=df.loc[(df['Class']=='Benign','Clump_Thickness')].mean()
print(average_Clump_Thickness)
# Out:
# 2.95633187773

# %%
df.loc[(df['Class']=='Benign') &
              (df['Clump_Thickness'].isnull()), 
              'Clump_Thickness']=average_Clump_Thickness

# %%
df.loc[(df['Class']=='Malignant') &( df['Clump_Thickness'] <=average_Clump_Thickness)]
# Out:
#           ID  Clump_Thickness  U_Cell_Size  U_Cell_Shape  Marg_Adhes  \
# 39   1091262              2.0            5             3           3
# 101  1167439              2.0            3             4           4
# 107  1170420              1.0            6             8          10
# 186  1206695              1.0            5             8           6
# 282   488173              1.0            4             3          10
# 353   850831              2.0            7            10          10
# 591  1295529              2.0            5             7           6
#
#      Epi_Cell_Size Bare_Nuc  Chromatin  Nucleoli  Mitoses      Class
# 39               6        7          7         5        1  Malignant
# 101              2        5          2         5        1  Malignant
# 107              8       10          5         7        1  Malignant
# 186              5        8          7        10        1  Malignant
# 282              4       10          5         6        1  Malignant
# ...

# %%
sb.pairplot(df,vars=cols,hue='Class')

# %%
df[cols].mean()
# Out:
# Clump_Thickness    4.417740
# U_Cell_Size        3.134478
# U_Cell_Shape       3.207439
# Marg_Adhes         2.806867
# Epi_Cell_Size      3.216023
# Chromatin          3.437768
# Nucleoli           2.866953
# Mitoses            1.589413
# dtype: float64

# %%
df[cols].median()
# Out:
# Clump_Thickness    4.0
# U_Cell_Size        1.0
# U_Cell_Shape       1.0
# Marg_Adhes         1.0
# Epi_Cell_Size      2.0
# Chromatin          3.0
# Nucleoli           1.0
# Mitoses            1.0
# dtype: float64

# %%
df.mode()
# Out:
#         ID  Clump_Thickness  U_Cell_Size  U_Cell_Shape  Marg_Adhes  \
# 0  1182404                1            1             1           1
#
#    Epi_Cell_Size Bare_Nuc  Chromatin  Nucleoli  Mitoses   Class
# 0              2        1          2         1        1  Benign

# %%
plt.figure(figsize=(10, 10))

for column_index, column in enumerate(df[cols].columns):
    if column == 'Class':
        continue
    plt.subplot(3, 3, column_index + 1)
    sb.violinplot(x='Class', y=column, data=df)

# %%
plt.figure(figsize=(10, 10))

for column_index, column in enumerate(df[cols].columns):
    if column == 'Class':
        continue
    plt.subplot(3, 3, column_index + 1)
    sb.boxplot(x='Class', y=column, data=df)
